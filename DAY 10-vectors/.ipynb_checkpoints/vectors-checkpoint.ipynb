# %%
112,321,442,343,23,413,534,765,907,908
# Out:
# (112, 321, 442, 343, 23, 413, 534, 765, 907, 908)

# %%
import statistics





data = [112, 321, 442, 343, 23, 413, 534, 765, 907, 908]
mean = statistics.mean(data)
variance = statistics.variance(data)

print(f"Mean: {mean}")
print(f"Sample Variance: {variance}")
# Out:
# Mean: 476.8
# Sample Variance: 93756.4
# Population Variance: 84380.76
