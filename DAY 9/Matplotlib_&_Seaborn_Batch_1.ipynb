# %% [markdown]
# # Matplotlib :
# ## It is popular python library used for data visualizations . It helps to create static , animated and interactive graphs in python.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Line Chart:
# ## It is used for show the trends over the time.

# %%
x = [3,7,5,9]
y = [1,2,3,4]
plt.plot(x,y, marker = 'o')
plt.title("Line Chart")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()

# %% [markdown]
# ### Bar Chart/graph :
# ### It is used for comapring quatities by categories.

# %%
x = ['A' , 'B', 'C' , 'D']
y = [35,55,40,60]

plt.bar(x,y , color = 'skyblue')
plt.show()

# %%
plt.barh(x,y,color = 'green')
plt.show()

# %% [markdown]
# ### Histogram
# ### It is used for showing the frequency ditribution of a dataset.

# %%
import numpy as np

data = np.random.randn(1000)

plt.hist(data , bins = 30 , color = 'red')
plt.grid()
plt.show()

# %% [markdown]
# ### Pie Chart:
# ### It is used to show the proportions or percentage of data.

# %%
subs = ['C++' , 'Java' , 'HTML' , 'Pyhton']
x = [25,40,15,20]

plt.pie(x , labels = subs , autopct = '%1.1f%%' , startangle = 90)
plt.show()

# %% [markdown]
# ### Scatter Plot:
# ### It used to show the relationship between two variables.

# %%
x = [12,4,6,17,13,27,25,41]
y = [89,102,111,95,112,118,109,121]

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Box plot (Whisker plot):
# ### It shows the Statistics summary like median , quartile and outliers.

# %%
x = [34,5,45,32,25,30,20,40,50 , 230]     

plt.boxplot(x)
plt.show()

# %%
### multiple line plot

x = [2,5,6,8,10]
y1 = [7,3,8,10,4]
y2 = [5,10,1,6,8]
y3 = [8,2,5,7,4]

plt.plot(x , y1 , marker ='*' , color = 'green')
plt.plot(x , y2 , marker ='o' , color = 'red')
plt.plot(x , y3 , marker ='+' , color = 'skyblue')

plt.show()

# %% [markdown]
# # Seaborn :
# ## It is powerful data visualization python library based on matplotlib. It provides high level and attractive statisticals graphs and plots.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\anjali vishawakarma\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
tip = sns.load_dataset('tips')

# %%
tip.head(6)

# %%
iris = sns.load_dataset('iris')

# %%
iris.head(6)

# %%
sns.lineplot(x = 'tip' , y = 'total_bill' , data = tip)
plt.title('line-plot')
plt.show()

# %%
sns.barplot(x = 'day' , y = 'total_bill' , data = tip)

# %%
# Countplot : It is used to count the occurences of categorical data.

sns.countplot(x='day' , data = tip)

# %%
# boxplot

# %%
sns.boxplot(x = 'day' , y = 'total_bill' , data = tip)

# %%
# violin plot:
#It is used for distribution and probability density.

sns.violinplot(x = 'day' , y = 'total_bill' , data = tip)

# %%
# swarm plot: 
#  It is used for display all the data points on categorical axis.

sns.swarmplot(x= 'day' , y = 'total_bill' , data = tip)

# %%
# pairplot:
#It is used to ploting pairwise relationships of dataset. 

sns.pairplot(iris , hue = 'species')

# %%
# heatmap :
# It is used to show the corelation of dataset.
coor = tip.corr()
cor = tip.corr(numeric_only = True)
sns.heatmap(cor , annot = True , cmap = 'coolwarm' )
